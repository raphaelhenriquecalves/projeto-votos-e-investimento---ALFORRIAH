# %% [markdown]
# # Projeto Candidato x Investimento
#
# ***

# %% [markdown]
# Este notebook tem o intuito de <b>estudar uma possível correlação entre financiamento eleitoral e numero de votos</b> obtidos por candidatos em eleições diretas. O estudo será feito nas seguintes etapas:
#
#
# <b><font color=green> 1. Coleta e limpeza de dados.</b></font>
#
# <b><font color=green> 2. Analise das variáveis</b></font>
#
#
# Abaixo seguem as etapas detalhadas:

# %% [markdown]
# ***
#
# ## 1. <font color=red>COLETA E LIMPEZA DE DADOS</font>

# %% [markdown]
# Inicialmente a coleta de dados foi feita através do endereço:
#
# > https://basedosdados.org/dataset/br-tse-eleicoes?bdm_table=detalhes_votacao_municipio_zona

# %%
pip install basedosdados
# Out:
# Requirement already satisfied: basedosdados in c:\users\user\anaconda3\lib\site-packages (1.6.4)
# Requirement already satisfied: pyaml==20.4.0 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (20.4.0)
# Requirement already satisfied: mkdocs-click<0.6.0,>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (0.5.0)
# Requirement already satisfied: pandas==1.2.4 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (1.2.4)
# Requirement already satisfied: google-cloud-bigquery-storage==1.1.0 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (1.1.0)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (1.0.0)
# Requirement already satisfied: tomlkit==0.7.0 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (0.7.0)
# Requirement already satisfied: pyarrow==6.0.0 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (6.0.0)
# Requirement already satisfied: ckanapi==4.6 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (4.6)
# Requirement already satisfied: pytest==6.0.2 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (6.0.2)
# Requirement already satisfied: ipykernel==5.3.4 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (5.3.4)
# Requirement already satisfied: importlib-metadata<5.0.0,>=4.11.3 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (4.12.0)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (0.10.2)
# Requirement already satisfied: mkdocstrings<0.19.0,>=0.18.1 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (0.18.1)
# Requirement already satisfied: google-cloud-storage==1.42.3 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (1.42.3)
# Requirement already satisfied: black==20.8b1 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (20.8b1)
# Requirement already satisfied: Jinja2==3.0.3 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (3.0.3)
# Requirement already satisfied: ruamel.yaml==0.17.10 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (0.17.10)
# Requirement already satisfied: click==8.0.3 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (8.0.3)
# Requirement already satisfied: mkdocs-material<9.0.0,>=8.2.7 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (8.3.9)
# Requirement already satisfied: google-cloud-bigquery==2.30.1 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (2.30.1)
# Requirement already satisfied: pandavro<2.0.0,>=1.6.0 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (1.7.1)
# Requirement already satisfied: tqdm==4.50.2 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (4.50.2)
# Requirement already satisfied: pandas-gbq<0.18.0,>=0.17.4 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (0.17.7)
# Requirement already satisfied: loguru<0.7.0,>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (0.6.0)
# Requirement already satisfied: mkdocs<2.0.0,>=1.2.3 in c:\users\user\anaconda3\lib\site-packages (from basedosdados) (1.3.1)
# Requirement already satisfied: typed-ast>=1.4.0 in c:\users\user\anaconda3\lib\site-packages (from black==20.8b1->basedosdados) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\user\anaconda3\lib\site-packages (from black==20.8b1->basedosdados) (3.10.0.2)
# Requirement already satisfied: pathspec<1,>=0.6 in c:\users\user\anaconda3\lib\site-packages (from black==20.8b1->basedosdados) (0.7.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\user\anaconda3\lib\site-packages (from black==20.8b1->basedosdados) (0.4.3)
# Requirement already satisfied: regex>=2020.1.8 in c:\users\user\anaconda3\lib\site-packages (from black==20.8b1->basedosdados) (2021.8.3)
# Requirement already satisfied: appdirs in c:\users\user\anaconda3\lib\site-packages (from black==20.8b1->basedosdados) (1.4.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from ckanapi==4.6->basedosdados) (58.0.4)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from ckanapi==4.6->basedosdados) (2.26.0)
# Requirement already satisfied: docopt in c:\users\user\anaconda3\lib\site-packages (from ckanapi==4.6->basedosdados) (0.6.2)
# Requirement already satisfied: python-slugify>=1.0 in c:\users\user\anaconda3\lib\site-packages (from ckanapi==4.6->basedosdados) (5.0.2)
# Requirement already satisfied: six<2.0,>=1.9 in c:\users\user\anaconda3\lib\site-packages (from ckanapi==4.6->basedosdados) (1.16.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click==8.0.3->basedosdados) (0.4.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.38.1 in c:\users\user\anaconda3\lib\site-packages (from google-cloud-bigquery==2.30.1->basedosdados) (1.47.0)
# Requirement already satisfied: packaging>=14.3 in c:\users\user\anaconda3\lib\site-packages (from google-cloud-bigquery==2.30.1->basedosdados) (21.0)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from google-cloud-bigquery==2.30.1->basedosdados) (2.3.3)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.29.0 in c:\users\user\anaconda3\lib\site-packages (from google-cloud-bigquery==2.30.1->basedosdados) (1.32.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in c:\users\user\anaconda3\lib\site-packages (from google-cloud-bigquery==2.30.1->basedosdados) (2.8.2)
# Requirement already satisfied: proto-plus>=1.10.0 in c:\users\user\anaconda3\lib\site-packages (from google-cloud-bigquery==2.30.1->basedosdados) (1.20.6)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\user\anaconda3\lib\site-packages (from google-cloud-bigquery==2.30.1->basedosdados) (3.20.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from google-cloud-bigquery==2.30.1->basedosdados) (2.3.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\users\user\anaconda3\lib\site-packages (from google-cloud-storage==1.42.3->basedosdados) (1.35.0)
# Requirement already satisfied: jupyter-client in c:\users\user\anaconda3\lib\site-packages (from ipykernel==5.3.4->basedosdados) (6.1.12)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel==5.3.4->basedosdados) (7.29.0)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel==5.3.4->basedosdados) (5.1.0)
# Requirement already satisfied: tornado>=4.2 in c:\users\user\anaconda3\lib\site-packages (from ipykernel==5.3.4->basedosdados) (6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from Jinja2==3.0.3->basedosdados) (2.1.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\user\anaconda3\lib\site-packages (from pandas==1.2.4->basedosdados) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\anaconda3\lib\site-packages (from pandas==1.2.4->basedosdados) (2021.3)
# Requirement already satisfied: PyYAML in c:\users\user\anaconda3\lib\site-packages (from pyaml==20.4.0->basedosdados) (6.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\user\anaconda3\lib\site-packages (from pytest==6.0.2->basedosdados) (1.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\user\anaconda3\lib\site-packages (from pytest==6.0.2->basedosdados) (8.10.0)
# Requirement already satisfied: iniconfig in c:\users\user\anaconda3\lib\site-packages (from pytest==6.0.2->basedosdados) (1.1.1)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\user\anaconda3\lib\site-packages (from pytest==6.0.2->basedosdados) (0.13.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\lib\site-packages (from pytest==6.0.2->basedosdados) (21.2.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\user\anaconda3\lib\site-packages (from pytest==6.0.2->basedosdados) (1.10.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in c:\users\user\anaconda3\lib\site-packages (from ruamel.yaml==0.17.10->basedosdados) (0.2.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\user\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.29.0->google-cloud-bigquery==2.30.1->basedosdados) (1.56.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage==1.42.3->basedosdados) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage==1.42.3->basedosdados) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage==1.42.3->basedosdados) (0.2.8)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery==2.30.1->basedosdados) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata<5.0.0,>=4.11.3->basedosdados) (3.6.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (3.0.20)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.1.2)
# Requirement already satisfied: pygments in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (2.12.0)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.7.5)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.8.2)
# Requirement already satisfied: qtconsole in c:\users\user\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->basedosdados) (5.1.1)
# Requirement already satisfied: jupyter-console in c:\users\user\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->basedosdados) (6.4.0)
# Requirement already satisfied: ipywidgets in c:\users\user\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->basedosdados) (7.6.5)
# Requirement already satisfied: nbconvert in c:\users\user\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->basedosdados) (6.1.0)
# Requirement already satisfied: notebook in c:\users\user\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->basedosdados) (6.4.5)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from loguru<0.7.0,>=0.6.0->basedosdados) (1.1.0)
# Requirement already satisfied: watchdog>=2.0 in c:\users\user\anaconda3\lib\site-packages (from mkdocs<2.0.0,>=1.2.3->basedosdados) (2.1.3)
# Requirement already satisfied: ghp-import>=1.0 in c:\users\user\anaconda3\lib\site-packages (from mkdocs<2.0.0,>=1.2.3->basedosdados) (2.1.0)
# Requirement already satisfied: Markdown<3.4,>=3.2.1 in c:\users\user\anaconda3\lib\site-packages (from mkdocs<2.0.0,>=1.2.3->basedosdados) (3.3.7)
# Requirement already satisfied: mergedeep>=1.3.4 in c:\users\user\anaconda3\lib\site-packages (from mkdocs<2.0.0,>=1.2.3->basedosdados) (1.3.4)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in c:\users\user\anaconda3\lib\site-packages (from mkdocs<2.0.0,>=1.2.3->basedosdados) (0.1)
# Requirement already satisfied: pymdown-extensions>=9.4 in c:\users\user\anaconda3\lib\site-packages (from mkdocs-material<9.0.0,>=8.2.7->basedosdados) (9.5)
# Requirement already satisfied: mkdocs-material-extensions>=1.0.3 in c:\users\user\anaconda3\lib\site-packages (from mkdocs-material<9.0.0,>=8.2.7->basedosdados) (1.0.3)
# Requirement already satisfied: mkdocs-autorefs>=0.3.1 in c:\users\user\anaconda3\lib\site-packages (from mkdocstrings<0.19.0,>=0.18.1->basedosdados) (0.4.1)
# Requirement already satisfied: mkdocstrings-python-legacy>=0.2 in c:\users\user\anaconda3\lib\site-packages (from mkdocstrings<0.19.0,>=0.18.1->basedosdados) (0.2.2)
# Requirement already satisfied: pytkdocs>=0.14 in c:\users\user\anaconda3\lib\site-packages (from mkdocstrings-python-legacy>=0.2->mkdocstrings<0.19.0,>=0.18.1->basedosdados) (0.16.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=14.3->google-cloud-bigquery==2.30.1->basedosdados) (3.0.4)
# Requirement already satisfied: db-dtypes<2.0.0,>=0.3.1 in c:\users\user\anaconda3\lib\site-packages (from pandas-gbq<0.18.0,>=0.17.4->basedosdados) (1.0.2)
# Requirement already satisfied: google-auth-oauthlib>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from pandas-gbq<0.18.0,>=0.17.4->basedosdados) (0.5.2)
# Requirement already satisfied: pydata-google-auth in c:\users\user\anaconda3\lib\site-packages (from pandas-gbq<0.18.0,>=0.17.4->basedosdados) (1.4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.0.1->pandas-gbq<0.18.0,>=0.17.4->basedosdados) (1.3.1)
# Requirement already satisfied: fastavro==1.5.1 in c:\users\user\anaconda3\lib\site-packages (from pandavro<2.0.0,>=1.6.0->basedosdados) (1.5.1)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel==5.3.4->basedosdados) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage==1.42.3->basedosdados) (0.4.8)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\user\anaconda3\lib\site-packages (from python-slugify>=1.0->ckanapi==4.6->basedosdados) (1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->ckanapi==4.6->basedosdados) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from requests->ckanapi==4.6->basedosdados) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->ckanapi==4.6->basedosdados) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->ckanapi==4.6->basedosdados) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.0.1->pandas-gbq<0.18.0,>=0.17.4->basedosdados) (3.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (1.0.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\user\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (4.8.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (0.18.0)
# Requirement already satisfied: argon2-cffi in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (20.1.0)
# Requirement already satisfied: prometheus-client in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (0.11.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (22.2.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (0.9.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->basedosdados) (228)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\user\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->basedosdados) (2.20)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.1.2)
# Requirement already satisfied: testpath in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.5.3)
# Requirement already satisfied: bleach in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (4.0.0)
# Requirement already satisfied: async-generator in c:\users\user\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\user\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->basedosdados) (0.5.1)
# Requirement already satisfied: qtpy in c:\users\user\anaconda3\lib\site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->basedosdados) (1.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import basedosdados as bd

# Para carregar o dado direto no pandas
df = bd.read_table(dataset_id='br_tse_eleicoes',
                   table_id='detalhes_votacao_municipio',
                   billing_project_id="projeto-alforriah-raphael")
# Out:
# Downloading: 100%|██████████| 292596/292596 [01:31<00:00, 3215.18rows/s]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     ano  turno       tipo_eleicao sigla_uf id_municipio id_municipio_tse  \
# 0  1994      1  eleicao ordinaria       AC      1200013             1120
# 1  1994      1  eleicao ordinaria       AC      1200013             1120
# 2  1994      1  eleicao ordinaria       AC      1200013             1120
# 3  1994      1  eleicao ordinaria       AC      1200013             1120
# 4  1994      1  eleicao ordinaria       AC      1200013             1120
#
#                cargo  aptos  secoes  secoes_agregadas  ...  comparecimento  \
# 0  deputado estadual   3332       0                 0  ...            2599
# 1   deputado federal   3332       0                 0  ...            2599
# 2         governador   3332       0                 0  ...            2599
# 3         presidente   6664       0                 0  ...            5198
# 4            senador   3332       0                 0  ...            2599
#
#    abstencoes  votos_validos  votos_brancos  votos_nulos  votos_legenda  \
# 0         733           2111            204          235             49
# 1         733           1678            455          376             90
# 2         733           2031            477           91              0
# 3        1466           4322            524          352              0
# 4         733           3570           1247          381              0
#
#    proporcao_comparecimento  proporcao_votos_validos  proporcao_votos_brancos  \
# 0                 78.001198                81.223549                 7.849173
# 1                 78.001198                64.563293                17.506733
# 2                 78.001198                78.145439                18.353212
# 3                 78.001198                83.147362                10.080800
# 4                 78.001198               137.360520                47.979992
#
#    proporcao_votos_nulos
# 0               9.041939
# 1              14.467103
# 2               3.501347
# 3               6.771835
# 4              14.659485
#
# [5 rows x 22 columns]

# %%
# verificando o tamanho do dataframe
df.shape
# Out:
# (292596, 22)

# %%
# verificando as colunas do dataframe
df.columns
# Out:
# Index(['ano', 'turno', 'tipo_eleicao', 'sigla_uf', 'id_municipio',
#        'id_municipio_tse', 'cargo', 'aptos', 'secoes', 'secoes_agregadas',
#        'aptos_totalizadas', 'secoes_totalizadas', 'comparecimento',
#        'abstencoes', 'votos_validos', 'votos_brancos', 'votos_nulos',
#        'votos_legenda', 'proporcao_comparecimento', 'proporcao_votos_validos',
#        'proporcao_votos_brancos', 'proporcao_votos_nulos'],
#       dtype='object')

# %%
# criando um dicionário com os valores únicos de cada coluna
categorias_variáveis={}

for coluna in df.columns:
    categorias_variáveis[coluna] = df[coluna].unique()

# %%
# olhando os valores emcontrados
categorias_variáveis
# Out:
# {'ano': <IntegerArray>
#  [1994, 1996, 1998, 2000, 2004, 2008, 2014, 2020, 2016, 2002, 2012, 2010, 2018,
#   2006]
#  Length: 14, dtype: Int64,
#  'turno': <IntegerArray>
#  [1, 2]
#  Length: 2, dtype: Int64,
#  'tipo_eleicao': array(['eleicao ordinaria', 'eleicoes suplementares 2008',
#         'eleicao suplementar de cabo frio',
#         'eleicao suplementar de rio das ostras',
#         'eleicao suplementar de teresopolis',
#         'rj - suplementar de aperibe', 'rj - suplementar de iguaba grande',
#         'rj - suplementar de laje do muriae',
#         'rj - suplementar de mangaratiba', 'rj - suplementar de paraty',
#         'eleicao sup de pres tancredo neves',
#         'eleicao suplem muquem do sao francisco',
#         'eleicao suplementar camamu-ba', 'eleicao suplementar de macarani',
#         'eleicao suplementar sidrolandia-ms',
#         'eleicoes municipais 2020 - ap',
#         'eleicao suplementar governador am', 'alto taquari-mt-jul-2017',
#         'conquista d oeste-mt-mar/2017',
#         'eleicao sup bom jesus do araguaia',
#         'eleicao sup planalto da serra-mt',
#         'eleicao sup ribeirao cascalheira',
#         'eleicao suplementar mirassol d oeste',
#         'eleicao suplementar primavera do leste',
#         'eleicao suplementar - cabedelo/pb',
#         'eleicao suplementar de araripe', 'eleicao suplementar tarrafas',
#         'nova eleicao - meruoca/ce', 'eleicao supl de frecheirinha',
#         'eleicao suplementar - aracoiaba/ce',
#         'eleicao suplementar - cascavel/ce',
#         'eleicao suplementar - croata',
#         'eleicao suplementar - iraucuba/ce',
#         'eleicao suplementar - prefeito',
#         'eleicao suplementar - tiangua/ce',
#         'suplementar - santana do cariri',
#         'eleicao suplem de caapiranga - am',
#         'eleicao suplementar novo aripuana-am', 'suplementar anama / am',
#         'suplementar novo airao / am', 'eleicao suplementar - cabeceiras',
#         'eleicao suplementar - flores de goias',
#         'eleicao suplementar - goiatuba', 'eleicao suplementar - nazario',
#         'eleicao suplementar - pires do rio',
#         'eleicao suplementar - sao domingos',
#         'eleicao suplementar bom jesus de goias',
#         'eleicao suplementar barra do pirai-rj',
#         'eleicao suplementar de natividade-rj',
#         'eleicao suplem brejo da madre de deus',
#         'eleicao suplementar de agua preta',
#         'eleicao suplementar de primavera',
#         'eleicao suplementar de santa maria',
#         'eleicao suplementar de munhoz de melo',
#         'suplementar nova prata do iguacu',
#         'eleicao suplementar de belo jardim pe',
#         'eleicao suplementar ipojuca pe', 'eleicao suplementar de moju',
#         'eleicao suplementar de tome-acu', 'gloria dÂ´oeste', 'juara',
#         'eleicao suplementar de calcoene-ap',
#         'eleicao suplem de boa vista do gurupi',
#         'eleicao suplementar itacaja-to',
#         'eleicao suplementar sandolandia-to',
#         'eleicao suplementar taguatinga-to',
#         'eleicao suplementar de camamu',
#         'eleicao suplementar de jeremoabo',
#         'eleicao suplementar de pilao arcado',
#         'nova eleicao 2017 - sangao',
#         'nova eleicao 2017 bom jardim da serra',
#         'nova eleicao mar/2020 - laurentino',
#         'nova eleicao out/2018 - vidal ramos',
#         'nova eleicao set/2017 - abelardo luz',
#         'eleicao suplementar miguel leao (pi)',
#         'pi-eleicao sup de brasileira', 'eleicao sup santa luzia do norte',
#         'eleicao suplementar de taipas do to',
#         'eleicao suplementar de castelo (es)',
#         'eleicao suplementar de fundao (es)',
#         'eleicao suplementar de irupi (es)',
#         'eleicao suplementar muqui (es)',
#         'eleicao suplementar - davinopolis',
#         'eleicao suplementar - divinopolis',
#         'eleicao suplementar - niquelandia (go)',
#         'eleicao suplementar - petrolina (go)',
#         'eleicao suplementar - planaltina',
#         'eleicao suplementar - serranopolis',
#         'eleicao suplementar - turvelandia',
#         'eleicao suplementar mimoso de goias', 'eleicoes suplementares',
#         'eleicao sup de santa maria do para',
#         'eleicao sup santa maria do para',
#         'eleicao supl de agua azul do norte',
#         'eleicao suplementar de marituba/pa',
#         'eleicao suplementar de palestina - pa',
#         'eleicao suplementar igarape-miri',
#         'eleicao suplementar guajara-mirim',
#         'eleicao suplementar pimenta bueno',
#         'eleicao suplementar rolim de moura',
#         'suplementar candeias do jamari',
#         'suplementar prefeito vilhena - ro',
#         'eleicao suplementar governador - to',
#         'eleicao suplement bela vista do ma',
#         'eleicao suplementar de bacabal',
#         'eleicao suplementar bituruna - pr',
#         'eleicao suplementar de cambira',
#         'eleicao suplementar de rolandia - pr',
#         'eleicao suplementar inacio martins',
#         'eleicao suplementar joaquim tavora',
#         'eleicao suplementar jundiai do sul',
#         'eleicao suplementar santa ines',
#         'eleicao suplementar congonhinhas',
#         'eleicao suplementar de foz do iguacu',
#         'eleicao suplementar de guaraquecaba',
#         'eleicao suplementar de moreira sales',
#         'eleicao suplementar de nova fatima',
#         'eleicao suplementar de pirai do sul',
#         'eleicao suplementar japira',
#         'eleicao suplementar nova laranjeiras', 'eleicao suplementar pien',
#         'eleicao suplementar primeiro de maio',
#         'eleicao suplementar quatigua',
#         'eleicao suplementar rancho alegre',
#         'sup de serranopolis do iguacu', 'agua boa mg - 67Âª ze',
#         'eleicao sup de cachoeira dourada',
#         'eleicao sup de sao joao do paraiso',
#         'eleicao suplementar de biquinhas',
#         'eleicao suplementar de diamantina',
#         'eleicao suplementar de ipiacu', 'eleicao suplementar de jampruca',
#         'mathias lobato mg - 119Âª ze', 'montezuma mg - 237Âª ze',
#         'novas eleicoes santana de cataguases',
#         'santa helena de minas mg - 4Âª ze',
#         'sao sebastiao da vargem alegre ze 178',
#         'eleicao supl de agua doce do norte es',
#         'eleicao suplementar de pedro canario',
#         'eleicao suplementar guarapari 2012', 'suplementar simoes',
#         'eleicao maj caicara do rio do vento/rn',
#         'eleicao majoritaria serra do mel/rn',
#         'eleicao suplementar - pedra grande',
#         'eleicao suplementar de carnaubais-rn',
#         'eleicao suplementar de luis gomes-rn',
#         'eleicao suplementar de passagem-rn',
#         'eleicao suplementar francisco dantas',
#         'eleicao suplementar ipanguacu-rn',
#         'eleicao suplementar mossoro-rn',
#         'eleicao suplementar de carmopolis-se',
#         'suplementar - riachao do dantas', 'suplementar de sao francisco',
#         'majoritaria - baln rincao', 'majoritaria - benedito novo',
#         'majoritaria - campo ere', 'majoritaria - criciuma',
#         'majoritaria - ponte serrada', 'majoritaria - tangara',
#         'eleicao suplementar de putinga',
#         'eleicao suplementar pinheiro machado',
#         'eleicao suplementar de arvorezinha',
#         'eleicao suplementar de bom jesus - rs',
#         'eleicao suplementar de butia', 'eleicao suplementar de gravatai',
#         'eleicao suplementar de ivoti-rs',
#         'eleicao suplementar de parai-rs',
#         'eleicao suplementar de parobe - rs',
#         'eleicao suplementar de salto do jacui',
#         'eleicao suplementar de sao vendelino',
#         'eleicao suplementar palmares do sul',
#         'eleicao suplementar sao vicente do sul',
#         'suplementar de alpestre - rs',
#         'eleicao sup conceicao do rio verde',
#         'eleicao supl nova porteirinha', 'eleicao suplementar aguanil',
#         'eleicao suplementar alvorada de minas',
#         'eleicao suplementar antonio dias',
#         'eleicao suplementar campo azul',
#         'eleicao suplementar campo florido', 'eleicao suplementar canaa',
#         'eleicao suplementar cristiano otoni',
#         'eleicao suplementar dionisio', 'eleicao suplementar eloi mendes',
#         'eleicao suplementar ervalia', 'eleicao suplementar guanhaes',
#         'eleicao suplementar guaraciama', 'eleicao suplementar ibiracatu',
#         'eleicao suplementar ibitiura de minas',
#         'eleicao suplementar ibitiura minas',
#         'eleicao suplementar ibituruna', 'eleicao suplementar ipatinga',
#         'eleicao suplementar itabirito', 'eleicao suplementar itanhomi',
#         'eleicao suplementar jordania', 'eleicao suplementar juatuba',
#         'eleicao suplementar pocrane',
#         'eleicao suplementar santa cruz salinas',
#         'eleicao suplementar santa luzia',
#         'eleicao suplementar santana da vargem',
#         'eleicao suplementar sao bento abade',
#         'eleicao suplementar sta rita de minas',
#         'eleicao suplementar timoteo', 'eleicao suplementar caarapo - ms',
#         'eleicao suplementar de japora - ms',
#         'eleicao suplementar miranda-ms', 'eleicao suplementar tacuru',
#         'eleicao suplementar de americana',
#         'eleicao suplementar de bento de abreu',
#         'eleicao suplementar de canas', 'eleicao suplementar de indiana',
#         'eleicao suplementar de itapolis',
#         'eleicao suplementar de jumirim',
#         'eleicao suplementar de paulo de faria',
#         'eleicao suplementar de vargem',
#         'nova eleicao - coronel macedo 7abr2013',
#         'nova eleicao - eldorado 7abr2013',
#         'nova eleicao - fernao 7abr2013',
#         'nova eleicao boa esperanca do sul', 'nova eleicao descalvado',
#         'nova eleicao ibate', 'nova eleicao itai',
#         'nova eleicao osvaldo cruz', 'nova eleicao pedrinhas paulista',
#         'nova eleicao santana do parnaiba', 'nova eleicao tabatinga',
#         'novas eleicoes - cananeia - 02/06/2013',
#         'novas eleicoes general salgado 2/6/13',
#         'soledade - nova eleicao 2013', 'eleicao suplementar campestre',
#         'eleicao suplementar espera feliz',
#         'eleicao suplementar de major isidoro',
#         'eleicao suplementar de palestina-al', 'nova eleicao petrolandia',
#         'suplementar bela vista', 'suplementar bonito',
#         'suplementar figueirao', 'suplementar jardim',
#         'suplementar sidrolandia', 'majoritaria - alm tamandare do sul',
#         'majoritaria - augusto pestana', 'majoritaria - colinas',
#         'majoritaria - crissiumal', 'majoritaria - dom feliciano',
#         'majoritaria - eugenio de castro',
#         'majoritaria - fortaleza dos valos',
#         'majoritaria - maximiliano de almeida',
#         'majoritaria - novo hamburgo', 'majoritaria - pedras altas',
#         'majoritaria - sao jose do ouro', 'majoritaria - sobradinho',
#         'majoritaria - triunfo', 'majoritaria - tucunduva',
#         'majoritaria - tupandi', 'eleicao suplementar amapari-ap',
#         'eleicao suplem sao jose da bela vista',
#         'eleicao suplementar cafelandia',
#         'eleicao suplementar de itatinga',
#         'eleicao suplementar de mairinque',
#         'eleicao suplementar de mombuca', 'eleicao suplementar mococa',
#         'suplementar bariri', 'suplementar cajamar',
#         'suplementar de araras', 'suplementar de bofete',
#         'suplementar de monte azul paulista',
#         'suplementar de paulinia 9/19', 'suplementar de rincao',
#         'suplementar de sandovalina',
#         'suplementar de sebastianopolis do sul',
#         'suplementar floreal - 08/19', 'suplementar general salgado',
#         'suplementar guaicara 27/10/19', 'suplementar lagoinha',
#         'suplementar macaubal', 'suplementar meridiano 08/19',
#         'suplementar mirandopolis 9/19',
#         'suplementar pirapora do bom jesus',
#         'suplementar santa cruz das palmeiras', 'suplementar turmalina',
#         'eleicao sup de sao jose de campestre',
#         'eleicao suplem de alto do rodrigues',
#         'eleicao suplementar de agua nova',
#         'eleicao suplementar de ceara-mirim',
#         'eleicao suplementar de galinhos',
#         'eleicao suplementar de guamare',
#         'eleicao suplementar de joao camara',
#         'eleicao suplementar de parau', 'eleicao suplementar de parazinho',
#         'eleicao suplementar de passa e fica',
#         'eleicao suplementar de pedro avelino',
#         'eleicao suplementar de pendencias',
#         'eleicao suplementar de santa cruz'], dtype=object),
#  'sigla_uf': array(['AC', 'AL', 'AM', 'MA', 'MS', 'GO', 'PI', 'RS', 'AP', 'RR', 'SE',
#         'BA', 'SC', 'TO', 'SP', 'ES', 'CE', 'MG', 'PB', 'RN', 'PA', 'DF',
#         'MT', 'PE', 'RO', 'PR', 'RJ', 'ZZ', 'VT'], dtype=object),
#  'id_municipio': array(['1200013', '1200054', '1200104', ..., '4314548', '4212650',
#         '4220000'], dtype=object),
#  'id_municipio_tse': array(['1120', '1570', '1058', ..., '99406', '99422', '99430'],
#        dtype=object),
#  'cargo': array(['deputado estadual', 'deputado federal', 'governador',
#         'presidente', 'senador', 'prefeito', 'vereador',
#         'deputado distrital'], dtype=object),
#  'aptos': <IntegerArray>
#  [  3332,   6664,   2473,   4946,   9118,  18236,   3312,   6624,   1751,
#     3502,
#   ...
#    37577,  46541,  20431,  31020, 188625,  31915,  21961,  60108,  96070,
#    76348]
#  Length: 32485, dtype: Int64,
#  'secoes': <IntegerArray>
#  [   0,   37,   42,  262,   80,   21,   11,   29,   13,   14,
#   ...
#   1218, 3760,  963,  956, 4228, 1190, 3859, 1249, 4018,  716]
#  Length: 1225, dtype: Int64,
#  'secoes_agregadas': <IntegerArray>
#  [  0,   1,  12,   3,   2,   5,   6,   4,   8,   7,
#   ...
#   165, 255, 137, 127, 279, 240, 106, 198, 229,  96]
#  Length: 174, dtype: Int64,
#  'aptos_totalizadas': <IntegerArray>
#  [     0,  11527,  11304,  92842,  22147,   7491,   4145,   8864,   3462,
#     4078,
#   ...
#    22680,  46541,  20431,  31020, 188625,  31915,  21961,  60108,  96070,
#    76348]
#  Length: 30157, dtype: Int64,
#  'secoes_totalizadas': <IntegerArray>
#  [   0,   37,   42,  262,   80,   21,   11,   29,   13,   14,
#   ...
#   1218, 3760,  963,  956, 4228, 1190, 3859, 1249, 4018,  716]
#  Length: 1225, dtype: Int64,
#  'comparecimento': <IntegerArray>
#  [  2599,   5198,   1896,   3792,   6886,  13772,   2609,   5218,   1246,
#     2492,
#   ...
#    19595,  39449,  26008, 158970,  27469,  50200,  41098,  81009,  64322,
#    31715]
#  Length: 32753, dtype: Int64,
#  'abstencoes': <IntegerArray>
#  [  733,  1466,   577,  1154,  2232,  4464,   703,  1406,   505,  1010,
#   ...
#   12831, 20713,  6162, 62905, 53762,  7738, 12157, 36026, 29655, 15061]
#  Length: 16384, dtype: Int64,
#  'votos_validos': <IntegerArray>
#  [  2111,   1678,   2031,   4322,   3570,   1521,   1236,   1561,   3208,
#     2848,
#   ...
#    47378,  46586,  67117,  47789,  18991, 186825,  36568, 147678,  46095,
#    76420]
#  Length: 48459, dtype: Int64,
#  'votos_brancos': <IntegerArray>
#  [  204,   455,   477,   524,  1247,   136,   327,   258,   320,   780,
#   ...
#   14056, 14360, 11372, 40532,  8223, 12465,  8409, 12792,  9581, 25629]
#  Length: 12377, dtype: Int64,
#  'votos_nulos': <IntegerArray>
#  [  235,   376,    91,   352,   381,   324,    77,   264,   164,  1292,
#   ...
#   15531, 51984, 17783, 10730, 20531, 15147, 11643, 55089, 16002,  9054]
#  Length: 14234, dtype: Int64,
#  'votos_legenda': <IntegerArray>
#  [   49,    90,     0,     4,     9,    19,    29,    25,    35,    11,
#   ...
#    9026,  7991, 18560, 11575, 10106,  3175,  2363, 10692,  7582,  4270]
#  Length: 8387, dtype: Int64,
#  'proporcao_comparecimento': array([78.001198, 76.668015, 75.52095 , ..., 85.390884, 77.749359,
#         85.728561]),
#  'proporcao_votos_validos': array([81.223549, 64.563293, 78.145439, ..., 93.348312, 93.48008 ,
#         94.380974]),
#  'proporcao_votos_brancos': array([ 7.8491726, 17.506733 , 18.353212 , ...,  1.258427 ,  1.9225411,
#          1.0725111]),
#  'proporcao_votos_nulos': array([ 9.0419388, 14.467103 ,  3.5013466, ...,  4.5973811,  3.2189851,
#          4.5465145])}

# %%
# criando um dataframe que contabiliza os valores nulos em cada variável
valores_nulos = {}

for coluna in df.columns:
    valores_nulos[coluna] = pd.isnull(df['ano']).sum()

# %%
# olhando a soma dos valores nulos de vada variável
valores_nulos
# Out:
# {'ano': 0,
#  'turno': 0,
#  'tipo_eleicao': 0,
#  'sigla_uf': 0,
#  'id_municipio': 0,
#  'id_municipio_tse': 0,
#  'cargo': 0,
#  'aptos': 0,
#  'secoes': 0,
#  'secoes_agregadas': 0,
#  'aptos_totalizadas': 0,
#  'secoes_totalizadas': 0,
#  'comparecimento': 0,
#  'abstencoes': 0,
#  'votos_validos': 0,
#  'votos_brancos': 0,
#  'votos_nulos': 0,
#  'votos_legenda': 0,
#  'proporcao_comparecimento': 0,
#  'proporcao_votos_validos': 0,
#  'proporcao_votos_brancos': 0,
#  'proporcao_votos_nulos': 0}

# %%
# verificando o número de municípios
df.groupby('id_municipio').sum().shape
# Out:
# (5570, 17)

# %%
# criando um dataframe com os códigos e os nomes dos municípios
url_municipios_tse = 'https://raw.githubusercontent.com/betafcc/Municipios-Brasileiros-TSE/fe2694220eb7280a3df01e985641f34078989aa8/municipios_brasileiros_tse.csv'

dados_id_municipios_tse = pd.read_csv(url_municipios_tse, index_col = 0)
dados_id_municipios_tse.drop('capital', axis=1, inplace=True)
dados_id_municipios_tse
# Out:
#             uf nome_municipio  codigo_ibge
# codigo_tse
# 1120        AC     ACRELÂNDIA      1200013
# 1570        AC   ASSIS BRASIL      1200054
# 1058        AC      BRASILÉIA      1200104
# 1007        AC         BUJARI      1200138
# 1015        AC       CAPIXABA      1200179
# ...         ..            ...          ...
# 96199       TO     TOCANTÍNIA      1721109
# 73458       TO       TUPIRAMA      1721257
# 73237       TO     TUPIRATINS      1721307
# 96652       TO   WANDERLÂNDIA      1722081
# 96431       TO        XAMBIOÁ      1722107
#
# [5570 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['ano', 'turno', 'tipo_eleicao', 'sigla_uf', 'id_municipio',
#        'id_municipio_tse', 'cargo', 'aptos', 'secoes', 'secoes_agregadas',
#        'aptos_totalizadas', 'secoes_totalizadas', 'comparecimento',
#        'abstencoes', 'votos_validos', 'votos_brancos', 'votos_nulos',
#        'votos_legenda', 'proporcao_comparecimento', 'proporcao_votos_validos',
#        'proporcao_votos_brancos', 'proporcao_votos_nulos'],
#       dtype='object')

# %%
dados_votos_validos = df[['ano', 'turno', 'tipo_eleicao', 'sigla_uf', 'id_municipio_tse', 'cargo', 'votos_validos', 'proporcao_votos_validos']]
dados_votos_validos
# Out:
#          ano  turno       tipo_eleicao sigla_uf id_municipio_tse  \
# 0       1994      1  eleicao ordinaria       AC             1120
# 1       1994      1  eleicao ordinaria       AC             1120
# 2       1994      1  eleicao ordinaria       AC             1120
# 3       1994      1  eleicao ordinaria       AC             1120
# 4       1994      1  eleicao ordinaria       AC             1120
# ...      ...    ...                ...      ...              ...
# 292591  2018      2  eleicao ordinaria       PR            74926
# 292592  2018      2  eleicao ordinaria       PR            74942
# 292593  2018      2  eleicao ordinaria       PR            74969
# 292594  2018      2  eleicao ordinaria       PR            79472
# 292595  2018      2  eleicao ordinaria       PR            79499
#
#                     cargo  votos_validos  proporcao_votos_validos
# 0       deputado estadual           2111                81.223549
# 1        deputado federal           1678                64.563293
# 2              governador           2031                78.145439
# 3              presidente           4322                83.147362
# 4                 senador           3570               137.360520
# ...                   ...            ...                      ...
# 292591         presidente           2077                93.348312
# 292592         presidente           3355                93.480080
# 292593         presidente           2670                94.379639
# 292594         presidente           4066                95.535713
# 292595         presidente           4048                94.380974
#
# [292596 rows x 8 columns]

# %%
dados_votos_validos.query("sigla_uf == 'AC'").groupby(['tipo_eleicao', 'cargo'])['votos_validos'].sum()
# Out:
# tipo_eleicao                 cargo
# eleicao ordinaria            deputado estadual    1972881
#                              deputado federal     1907496
#                              governador           2635611
#                              prefeito             2524246
#                              presidente           3879011
#                              senador              3013003
#                              vereador             2010210
# eleicoes suplementares 2008  prefeito               10608
# Name: votos_validos, dtype: Int64

# %%
dados_votos_validos.head()
# Out:
#     ano  turno       tipo_eleicao sigla_uf id_municipio_tse  \
# 0  1994      1  eleicao ordinaria       AC             1120
# 1  1994      1  eleicao ordinaria       AC             1120
# 2  1994      1  eleicao ordinaria       AC             1120
# 3  1994      1  eleicao ordinaria       AC             1120
# 4  1994      1  eleicao ordinaria       AC             1120
#
#                cargo  votos_validos  proporcao_votos_validos
# 0  deputado estadual           2111                81.223549
# 1   deputado federal           1678                64.563293
# 2         governador           2031                78.145439
# 3         presidente           4322                83.147362
# 4            senador           3570               137.360520

# %%
import basedosdados as bd

# Para carregar o dado direto no pandas
df2 = bd.read_table(dataset_id='br_tse_eleicoes',
                   table_id='resultados_candidato_municipio',
                   billing_project_id="projeto-alforriah-raphael")
# Out:
# Downloading:  38%|███▊      | 8832231/23308865 [21:02<33:42, 7157.02rows/s]
